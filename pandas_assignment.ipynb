# %%
import pandas as pd

# %%
data = {
      'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve'],
      'Age': [24, 27, 22, 32, 29],
      'Department': ['HR', 'Finance', 'IT', 'Marketing', 'HR'],
      'Salary': [45000, 54000, 50000, 62000, 47000]
  }

# %%
df_1 = pd.DataFrame(data)
df_1
# Out:
#       Name  Age Department  Salary
# 0    Alice   24         HR   45000
# 1      Bob   27    Finance   54000
# 2  Charlie   22         IT   50000
# 3    Diana   32  Marketing   62000
# 4      Eve   29         HR   47000

# %%
df_1.head()
# Out:
#       Name  Age Department  Salary
# 0    Alice   24         HR   45000
# 1      Bob   27    Finance   54000
# 2  Charlie   22         IT   50000
# 3    Diana   32  Marketing   62000
# 4      Eve   29         HR   47000

# %%
summary = df_1[['Age','Salary']].describe()
summary
# Out:
#              Age        Salary
# count   5.000000      5.000000
# mean   26.800000  51600.000000
# std     3.962323   6730.527468
# min    22.000000  45000.000000
# 25%    24.000000  47000.000000
# 50%    27.000000  50000.000000
# 75%    29.000000  54000.000000
# max    32.000000  62000.000000

# %%
average_salary = df[df['Department'] == 'HR']['Salary'].mean()
average_salary
# Out:
# 46000.0

# %%
df_1['Bouns'] = df_1['Salary'] * 0.10

df_1
# Out:
#       Name  Age Department  Salary   Bouns
# 0    Alice   24         HR   45000  4500.0
# 1      Bob   27    Finance   54000  5400.0
# 2  Charlie   22         IT   50000  5000.0
# 3    Diana   32  Marketing   62000  6200.0
# 4      Eve   29         HR   47000  4700.0

# %%
age = df_1[df_1['Age'].between(25,30)]
age
# Out:
#   Name  Age Department  Salary   Bouns
# 1  Bob   27    Finance   54000  5400.0
# 4  Eve   29         HR   47000  4700.0

# %%
groupby_df = df_1.groupby('Department')['Salary'].mean()
groupby_df
# Out:
# Department
# Finance      54000.0
# HR           46000.0
# IT           50000.0
# Marketing    62000.0
# Name: Salary, dtype: float64

# %%
sort_df = df_1.sort_values(by = 'Salary', ascending = True)
sort_df
# Out:
#       Name  Age Department  Salary   Bouns
# 0    Alice   24         HR   45000  4500.0
# 4      Eve   29         HR   47000  4700.0
# 2  Charlie   22         IT   50000  5000.0
# 1      Bob   27    Finance   54000  5400.0
# 3    Diana   32  Marketing   62000  6200.0

# %%
df.to_csv('Sorted_data.csv',index = False)
